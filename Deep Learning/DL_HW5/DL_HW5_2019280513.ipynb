# %% [markdown]
# #  HW5 Sentence-level Sentiment Classification with PyTorch

# %%
from torchtext import data, datasets
from torchtext.vocab import Vectors, GloVe, CharNGram, FastText
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np

# %% [markdown]
# ## Load Data

# %%
TEXT = data.Field()
LABEL = data.Field(sequential=False,dtype=torch.long)
train, val, test = datasets.SST.splits(
    TEXT, LABEL, fine_grained=True, train_subtrees=False)

# %%
# DATA
print('train.fields', train.fields)
print('len(train)', len(train))
print('vars(train[0])', vars(train[0]))
# Out:
# train.fields {'text': <torchtext.data.field.Field object at 0x121a01410>, 'label': <torchtext.data.field.Field object at 0x121a013d0>}
# len(train) 8544
# vars(train[0]) {'text': ['The', 'Rock', 'is', 'destined', 'to', 'be', 'the', '21st', 'Century', "'s", 'new', '``', 'Conan', "''", 'and', 'that', 'he', "'s", 'going', 'to', 'make', 'a', 'splash', 'even', 'greater', 'than', 'Arnold', 'Schwarzenegger', ',', 'Jean-Claud', 'Van', 'Damme', 'or', 'Steven', 'Segal', '.'], 'label': 'positive'}

# %%
# build the vocabulary
# you can use other pretrained vectors, refer to https://github.com/pytorch/text/blob/master/torchtext/vocab.py
TEXT.build_vocab(train, vectors=Vectors(name='vector.txt', cache='.data/'))
LABEL.build_vocab(train)
# We can also see the vocabulary directly using either the stoi (string to int) or itos (int to string) method.
print(TEXT.vocab.itos[:10])
print(LABEL.vocab.stoi)
print(TEXT.vocab.freqs.most_common(20))
# Out:
# ['<unk>', '<pad>', '.', ',', 'the', 'and', 'a', 'of', 'to', "'s"]
# defaultdict(<bound method Vocab._default_unk_index of <torchtext.vocab.Vocab object at 0x1a26c9aed0>>, {'<unk>': 0, 'positive': 1, 'negative': 2, 'neutral': 3, 'very positive': 4, 'very negative': 5})
# [('.', 8024), (',', 7131), ('the', 6037), ('and', 4431), ('a', 4403), ('of', 4386), ('to', 2995), ("'s", 2544), ('is', 2536), ('that', 1915), ('in', 1789), ('it', 1775), ('The', 1265), ('as', 1200), ('film', 1152), ('but', 1076), ('with', 1071), ('for', 963), ('movie', 959), ('its', 912)]

# %%
# vocab
print('len(TEXT.vocab)', len(TEXT.vocab))
print('TEXT.vocab.vectors.size()', TEXT.vocab.vectors.size())
# Out:
# len(TEXT.vocab) 18280
# TEXT.vocab.vectors.size() torch.Size([18280, 300])

# %%
# splits the data
train_iter, val_iter, test_iter = data.BucketIterator.splits(
    (train, val, test), batch_size=64)

# %%
pretrained_embeddings = TEXT.vocab.vectors

print(pretrained_embeddings.shape)
# Out:
# torch.Size([18280, 300])

# %% [markdown]
# # BIDIRECTIONAL LSTM

# %%
# Bidirectional lstm
class BD_LSTM(nn.Module):
    def __init__(self, input_dim, embedding_dim, hidden_dim, output_dim):
        super(BD_LSTM, self).__init__()
        self.word_embeddings = nn.Embedding(input_dim, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, bidirectional = True)
        self.fc = nn.Linear(hidden_dim * 2, output_dim)
        
    def forward(self, sentence):
        embedded_text = self.word_embeddings(sentence)
        lstm_out, _ = self.lstm(embedded_text)
        return self.fc(lstm_out[-1])

# %% [markdown]
# ## Training

# %%
model = BD_LSTM(len(TEXT.vocab), pretrained_embeddings.shape[1], 256, 5)
model.word_embeddings.weight.data.copy_(pretrained_embeddings)
optimizer = optim.Adam(model.parameters(), lr=0.001)
loss_function = nn.CrossEntropyLoss()

# %%
#Store values into arrays to calculate the result
train_acc, train_loss, val_acc, val_loss = [], [], [], []
iter = 0
epoch_num = 20

print(' ')
print("__________Training__________________")
for epoch in range(epoch_num):
    count = 1
    model.train()
    for batch in train_iter:
        iter = iter + 1
        targets = batch.label
        targets = targets.sub(1)
        X = batch.text
        optimizer.zero_grad()
        tag_scores = model(X)
        tag_scores = tag_scores.squeeze(1)
        loss = loss_function(tag_scores, targets)
        loss.backward()
        
        _, predicted = torch.max(tag_scores, 1)
        correct = (predicted == targets).float()
        batch_acc = correct.sum() / len(correct)
        
        optimizer.step()
        
        train_acc.append(batch_acc.item())
        train_loss.append(loss.item() / len(train_iter))
        if iter % epoch_num == 0:
            print( count,".", "Batch of " ,epoch_num, " training accuracy: {:.4f}".format(np.mean(train_acc[-epoch_num:])))
            count+=1
        
    print("Epoch ", epoch, ", train accuracy: {:.4f}".format(np.mean(train_acc[-len(train_iter):])))
    
    model.eval()
    with torch.no_grad():
        for batch in val_iter:
            targets = batch.label
            targets = targets.sub(1)
            tag_scores = model(batch.text)
            tag_scores = tag_scores.squeeze(1)
            loss = loss_function(tag_scores, targets)
            _, predicted = torch.max(tag_scores, 1)
            correct = (predicted == targets).float()
            batch_acc = correct.sum() / len(correct)
            val_acc.append(batch_acc.item())
            val_loss.append(loss.item() / len(val_iter))
    
    print("Epoch ", epoch, ", validation accuracy: {:.4f}".format(np.mean(val_acc[-len(val_iter):])))
    print('__________________________________')
# Out:
#
# __________Training__________________
# 1 . Batch of  20  training accuracy: 0.2656
# 2 . Batch of  20  training accuracy: 0.2625
# 3 . Batch of  20  training accuracy: 0.2781
# 4 . Batch of  20  training accuracy: 0.2570
# 5 . Batch of  20  training accuracy: 0.2680
# 6 . Batch of  20  training accuracy: 0.2742
# Epoch  0 , train accuracy: 0.2664
# Epoch  0 , validation accuracy: 0.2515
# __________________________________
# 1 . Batch of  20  training accuracy: 0.2633
# 2 . Batch of  20  training accuracy: 0.2742
# 3 . Batch of  20  training accuracy: 0.2609
# 4 . Batch of  20  training accuracy: 0.2805
# 5 . Batch of  20  training accuracy: 0.2703
# 6 . Batch of  20  training accuracy: 0.2672
# 7 . Batch of  20  training accuracy: 0.2867
# Epoch  1 , train accuracy: 0.2733
# Epoch  1 , validation accuracy: 0.2507
# __________________________________
# 1 . Batch of  20  training accuracy: 0.2703
# 2 . Batch of  20  training accuracy: 0.2648
# 3 . Batch of  20  training accuracy: 0.2555
# 4 . Batch of  20  training accuracy: 0.2820
# 5 . Batch of  20  training accuracy: 0.2664
# 6 . Batch of  20  training accuracy: 0.2672
# 7 . Batch of  20  training accuracy: 0.3008
# Epoch  2 , train accuracy: 0.2715
# Epoch  2 , validation accuracy: 0.3590
# __________________________________
# 1 . Batch of  20  training accuracy: 0.2883
# 2 . Batch of  20  training accuracy: 0.2930
# 3 . Batch of  20  training accuracy: 0.2594
# 4 . Batch of  20  training accuracy: 0.2844
# 5 . Batch of  20  training accuracy: 0.2555
# 6 . Batch of  20  training accuracy: 0.3047
# Epoch  3 , train accuracy: 0.2865
# Epoch  3 , validation accuracy: 0.2802
# __________________________________
# 1 . Batch of  20  training accuracy: 0.3234
# 2 . Batch of  20  training accuracy: 0.3031
# 3 . Batch of  20  training accuracy: 0.2609
# 4 . Batch of  20  training accuracy: 0.2789
# 5 . Batch of  20  training accuracy: 0.2703
# 6 . Batch of  20  training accuracy: 0.2875
# 7 . Batch of  20  training accuracy: 0.2539
# Epoch  4 , train accuracy: 0.2761
# Epoch  4 , validation accuracy: 0.2507
# __________________________________
# 1 . Batch of  20  training accuracy: 0.2719
# 2 . Batch of  20  training accuracy: 0.2977
# 3 . Batch of  20  training accuracy: 0.2594
# 4 . Batch of  20  training accuracy: 0.2609
# 5 . Batch of  20  training accuracy: 0.2875
# 6 . Batch of  20  training accuracy: 0.2578
# 7 . Batch of  20  training accuracy: 0.2727
# Epoch  5 , train accuracy: 0.2745
# Epoch  5 , validation accuracy: 0.3279
# __________________________________
# 1 . Batch of  20  training accuracy: 0.2680
# 2 . Batch of  20  training accuracy: 0.2773
# 3 . Batch of  20  training accuracy: 0.2664
# 4 . Batch of  20  training accuracy: 0.2602
# 5 . Batch of  20  training accuracy: 0.2609
# 6 . Batch of  20  training accuracy: 0.2742
# Epoch  6 , train accuracy: 0.2697
# Epoch  6 , validation accuracy: 0.2533
# __________________________________
# 1 . Batch of  20  training accuracy: 0.2820
# 2 . Batch of  20  training accuracy: 0.2852
# 3 . Batch of  20  training accuracy: 0.2734
# 4 . Batch of  20  training accuracy: 0.2672
# 5 . Batch of  20  training accuracy: 0.2695
# 6 . Batch of  20  training accuracy: 0.2687
# 7 . Batch of  20  training accuracy: 0.2578
# Epoch  7 , train accuracy: 0.2718
# Epoch  7 , validation accuracy: 0.2559
# __________________________________
# 1 . Batch of  20  training accuracy: 0.2867
# 2 . Batch of  20  training accuracy: 0.2648
# 3 . Batch of  20  training accuracy: 0.3469
# 4 . Batch of  20  training accuracy: 0.3539
# 5 . Batch of  20  training accuracy: 0.3578
# 6 . Batch of  20  training accuracy: 0.3625
# 7 . Batch of  20  training accuracy: 0.4094
# Epoch  8 , train accuracy: 0.3467
# Epoch  8 , validation accuracy: 0.3877
# __________________________________
# 1 . Batch of  20  training accuracy: 0.4195
# 2 . Batch of  20  training accuracy: 0.4383
# 3 . Batch of  20  training accuracy: 0.4562
# 4 . Batch of  20  training accuracy: 0.4750
# 5 . Batch of  20  training accuracy: 0.4648
# 6 . Batch of  20  training accuracy: 0.4773
# 7 . Batch of  20  training accuracy: 0.4594
# Epoch  9 , train accuracy: 0.4591
# Epoch  9 , validation accuracy: 0.4034
# __________________________________
# 1 . Batch of  20  training accuracy: 0.5484
# 2 . Batch of  20  training accuracy: 0.5766
# 3 . Batch of  20  training accuracy: 0.5766
# 4 . Batch of  20  training accuracy: 0.5742
# 5 . Batch of  20  training accuracy: 0.5711
# 6 . Batch of  20  training accuracy: 0.5609
# Epoch  10 , train accuracy: 0.5700
# Epoch  10 , validation accuracy: 0.4059
# __________________________________
# 1 . Batch of  20  training accuracy: 0.6242
# 2 . Batch of  20  training accuracy: 0.7148
# 3 . Batch of  20  training accuracy: 0.6898
# 4 . Batch of  20  training accuracy: 0.7148
# 5 . Batch of  20  training accuracy: 0.7086
# 6 . Batch of  20  training accuracy: 0.6977
# 7 . Batch of  20  training accuracy: 0.7211
# Epoch  11 , train accuracy: 0.7060
# Epoch  11 , validation accuracy: 0.3930
# __________________________________
# 1 . Batch of  20  training accuracy: 0.7484
# 2 . Batch of  20  training accuracy: 0.8039
# 3 . Batch of  20  training accuracy: 0.8148
# 4 . Batch of  20  training accuracy: 0.8023
# 5 . Batch of  20  training accuracy: 0.8133
# 6 . Batch of  20  training accuracy: 0.7898
# 7 . Batch of  20  training accuracy: 0.8375
# Epoch  12 , train accuracy: 0.8089
# Epoch  12 , validation accuracy: 0.3894
# __________________________________
# 1 . Batch of  20  training accuracy: 0.8859
# 2 . Batch of  20  training accuracy: 0.8836
# 3 . Batch of  20  training accuracy: 0.8773
# 4 . Batch of  20  training accuracy: 0.8805
# 5 . Batch of  20  training accuracy: 0.8773
# 6 . Batch of  20  training accuracy: 0.8398
# Epoch  13 , train accuracy: 0.8747
# Epoch  13 , validation accuracy: 0.3895
# __________________________________
# 1 . Batch of  20  training accuracy: 0.8836
# 2 . Batch of  20  training accuracy: 0.9281
# 3 . Batch of  20  training accuracy: 0.9320
# 4 . Batch of  20  training accuracy: 0.9117
# 5 . Batch of  20  training accuracy: 0.9328
# 6 . Batch of  20  training accuracy: 0.9336
# 7 . Batch of  20  training accuracy: 0.9203
# Epoch  14 , train accuracy: 0.9261
# Epoch  14 , validation accuracy: 0.3791
# __________________________________
# 1 . Batch of  20  training accuracy: 0.9359
# 2 . Batch of  20  training accuracy: 0.9578
# 3 . Batch of  20  training accuracy: 0.9570
# 4 . Batch of  20  training accuracy: 0.9430
# 5 . Batch of  20  training accuracy: 0.9531
# 6 . Batch of  20  training accuracy: 0.9414
# 7 . Batch of  20  training accuracy: 0.9586
# Epoch  15 , train accuracy: 0.9516
# Epoch  15 , validation accuracy: 0.3894
# __________________________________
# 1 . Batch of  20  training accuracy: 0.9508
# 2 . Batch of  20  training accuracy: 0.9602
# 3 . Batch of  20  training accuracy: 0.9664
# 4 . Batch of  20  training accuracy: 0.9633
# 5 . Batch of  20  training accuracy: 0.9563
# 6 . Batch of  20  training accuracy: 0.9609
# Epoch  16 , train accuracy: 0.9616
# Epoch  16 , validation accuracy: 0.3817
# __________________________________
# 1 . Batch of  20  training accuracy: 0.9703
# 2 . Batch of  20  training accuracy: 0.9734
# 3 . Batch of  20  training accuracy: 0.9750
# 4 . Batch of  20  training accuracy: 0.9781
# 5 . Batch of  20  training accuracy: 0.9750
# 6 . Batch of  20  training accuracy: 0.9664
# 7 . Batch of  20  training accuracy: 0.9688
# Epoch  17 , train accuracy: 0.9729
# Epoch  17 , validation accuracy: 0.3886
# __________________________________
# 1 . Batch of  20  training accuracy: 0.9719
# 2 . Batch of  20  training accuracy: 0.9758
# 3 . Batch of  20  training accuracy: 0.9758
# 4 . Batch of  20  training accuracy: 0.9867
# 5 . Batch of  20  training accuracy: 0.9820
# 6 . Batch of  20  training accuracy: 0.9797
# 7 . Batch of  20  training accuracy: 0.9820
# Epoch  18 , train accuracy: 0.9796
# Epoch  18 , validation accuracy: 0.3790
# __________________________________
# 1 . Batch of  20  training accuracy: 0.9820
# 2 . Batch of  20  training accuracy: 0.9852
# 3 . Batch of  20  training accuracy: 0.9781
# 4 . Batch of  20  training accuracy: 0.9820
# 5 . Batch of  20  training accuracy: 0.9852
# 6 . Batch of  20  training accuracy: 0.9789
# 7 . Batch of  20  training accuracy: 0.9781
# Epoch  19 , train accuracy: 0.9816
# Epoch  19 , validation accuracy: 0.3773
# __________________________________

# %% [markdown]
# ## Testing

# %%
test_acc = []
test_loss = []
model.eval()
with torch.no_grad():
    for batch in test_iter:
        targets = batch.label
        targets = targets.sub(1)
        tag_scores = model(batch.text)
        tag_scores = tag_scores.squeeze(1)
        loss = loss_function(tag_scores, targets)
        _, predicted = torch.max(tag_scores, 1)
        correct = (predicted == targets).float()
        batch_acc = correct.sum() / len(correct)
    test_acc.append(batch_acc.item())
    test_loss.append(loss.item())
    
print("Test accuracy:  {:.4f}".format(np.mean(test_acc)))
# Out:
# Test accuracy:  0.4118

# %% [markdown]
# ## Plot and Results

# %%
import matplotlib.pyplot as plt

# Training Results
plt.figure(figsize=(10, 5))
plt.title('Training Accuracy', fontsize=20)
plt.plot(train_acc)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.title('Training Loss', fontsize=20)
plt.plot(train_loss)
plt.show()

# %%
# Validation Results
plt.figure(figsize=(10, 5))
plt.title('Validation Accuracy', fontsize=20)
plt.plot(val_acc)
plt.show()

# %%
# Validation Results
plt.figure(figsize=(10, 5))
plt.title('Validation Loss', fontsize=20)
plt.plot(val_loss)
plt.show()

# %%
print("final result")
print("----------------------")

print("Test loss:  {:.4f}".format(np.mean(test_loss)))
print("Test accuracy:  {:.4f}".format(np.mean(test_acc)))
# Out:
# final result
# ----------------------
# Test loss:  3.4233
# Test accuracy:  0.4118
